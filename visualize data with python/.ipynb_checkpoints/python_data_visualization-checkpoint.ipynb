# %% [markdown]
# # Data Visualization

# %% [markdown]
# ## The presentation of data in graphical or pictorial fomat.

# %% [markdown]
# # Column graph

# %% [markdown]
# ### Useful for comparisons.
# ### Useful for tracking data sets over time.

# %% [markdown]
# # Bar graph

# %% [markdown]
# ### Allows more room for labels and categories.
# ### a column graph but in a horizontal orientation.

# %% [markdown]
# # Pie chart

# %% [markdown]
# ### Visualization of parts of a whole percentage.
# ### All parts should add up to a total of 100%.

# %% [markdown]
# # Stacked bar graph

# %% [markdown]
# ### Combines elements of bar and pie chart.
# ### Useful for preseting totals, trends, and proportions.

# %% [markdown]
# # Clustered bar chart

# %% [markdown]
# ### Useful for presenting how secondary categories rank within primary categories.

# %% [markdown]
# # Line graph

# %% [markdown]
# ### Reveals trends, progress, and changes over time.
# ### Works best with a continous data set.

# %% [markdown]
# # Histogram

# %% [markdown]
# ### Depicts frequency values.
# ### The x-axis is for the bins or intervals while the y-axis is for the frequency.

# %% [markdown]
# # Coding exercise 2.8

# %%
import array as arr

def resultAverage(result):
    print("average buy for 5 weeks:",result)
    
onlineBuy = [19,29,17,24,16]
    
data = arr.array("i", onlineBuy)
items = data[0:5]
itemList = items.tolist()

def getAverage(data):
    dataSum = sum(data)
    dataLen = len(data)
    average = dataSum / dataLen
    
    return average

averageResult = getAverage(itemList)

resultAverage(averageResult)
# Out:
# average buy for 5 weeks: 21.0

# %% [markdown]
# # Preparing with data

# %% [markdown]
# # Pandas

# %% [markdown]
# ## Create a dataframe, sales, from csvfile, all_sales

# %%
import pandas as pd
import matplotlib.pyplot as plt
sales = pd.read_csv("all_sales.csv")
sales.info()
sales.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 186850 entries, 0 to 186849
# Data columns (total 6 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
# dtypes: object(6)
# memory usage: 8.6+ MB
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
# ...

# %% [markdown]
# ## check the total number of blank rows

# %%
sales.isnull().sum()
# Out:
# Order ID            545
# Product             545
# Quantity Ordered    545
# Price Each          545
# Order Date          545
# Purchase Address    545
# dtype: int64

# %% [markdown]
# ## remove all nulls/blanks

# %%
sales = sales.dropna() # remove all null value 
sales.isnull().sum()
# Out:
# Order ID            0
# Product             0
# Quantity Ordered    0
# Price Each          0
# Order Date          0
# Purchase Address    0
# dtype: int64

# %%
sales.head(10)
# Out:
#    Order ID                     Product Quantity Ordered Price Each  \
# 0    176558        USB-C Charging Cable                2      11.95
# 2    176559  Bose SoundSport Headphones                1      99.99
# 3    176560                Google Phone                1        600
# 4    176560            Wired Headphones                1      11.99
# 5    176561            Wired Headphones                1      11.99
# 6    176562        USB-C Charging Cable                1      11.95
# 7    176563  Bose SoundSport Headphones                1      99.99
# 8    176564        USB-C Charging Cable                1      11.95
# 9    176565          Macbook Pro Laptop                1       1700
# 10   176566            Wired Headphones                1      11.99
#
#         Order Date                        Purchase Address
# 0   04/19/19 08:46            917 1st St, Dallas, TX 75001
# 2   04/07/19 22:30       682 Chestnut St, Boston, MA 02215
# ...

# %% [markdown]
# ## Create the month column from the order date.

# %%
sales["Month"] = sales["Order Date"].str[0:2]
sales.info()
sales.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 186305 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          186305 non-null  object
#  1   Product           186305 non-null  object
#  2   Quantity Ordered  186305 non-null  object
#  3   Price Each        186305 non-null  object
#  4   Order Date        186305 non-null  object
#  5   Purchase Address  186305 non-null  object
#  6   Month             186305 non-null  object
# dtypes: object(7)
# memory usage: 11.4+ MB
#    Order ID                     Product Quantity Ordered Price Each  \
# 0    176558        USB-C Charging Cable                2      11.95
# 2    176559  Bose SoundSport Headphones                1      99.99
# 3    176560                Google Phone                1        600
# 4    176560            Wired Headphones                1      11.99
# ...

# %% [markdown]
# ## Convert data type of the month column form object to integer

# %% [markdown]
# ## Create or_dump dataframe to check the "or's" in the month column

# %%
orDumpFrame = sales[sales["Month"] == "Or"]
orDumpFrame.head(10)
# Out:
#       Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 519   Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1149  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 1155  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2878  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 2893  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3036  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3209  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 3618  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 4138  Order ID  Product  Quantity Ordered  Price Each  Order Date
# 4645  Order ID  Product  Quantity Ordered  Price Each  Order Date
#
#       Purchase Address Month
# 519   Purchase Address    Or
# 1149  Purchase Address    Or
# 1155  Purchase Address    Or
# 2878  Purchase Address    Or
# 2893  Purchase Address    Or
# 3036  Purchase Address    Or
# ...

# %% [markdown]
# ## remove "or's" from the month column

# %%
sales = sales[sales["Month"] != "Or"]
sales.head(10)
# Out:
#    Order ID                     Product Quantity Ordered Price Each  \
# 0    176558        USB-C Charging Cable                2      11.95
# 2    176559  Bose SoundSport Headphones                1      99.99
# 3    176560                Google Phone                1        600
# 4    176560            Wired Headphones                1      11.99
# 5    176561            Wired Headphones                1      11.99
# 6    176562        USB-C Charging Cable                1      11.95
# 7    176563  Bose SoundSport Headphones                1      99.99
# 8    176564        USB-C Charging Cable                1      11.95
# 9    176565          Macbook Pro Laptop                1       1700
# 10   176566            Wired Headphones                1      11.99
#
#         Order Date                        Purchase Address Month
# 0   04/19/19 08:46            917 1st St, Dallas, TX 75001    04
# 2   04/07/19 22:30       682 Chestnut St, Boston, MA 02215    04
# ...

# %%
sales["Month"] = sales["Month"].astype("int32")
sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  object
#  3   Price Each        185950 non-null  object
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  int32
# dtypes: int32(1), object(6)
# memory usage: 10.6+ MB

# %% [markdown]
# ## Convert Quantity Order and Price Each columns to the correct data type.

# %%
sales["Quantity Ordered"] = pd.to_numeric(sales["Quantity Ordered"])
sales["Price Each"] = pd.to_numeric(sales["Price Each"])
sales.info()
sales.head(10)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 185950 entries, 0 to 186849
# Data columns (total 7 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Order ID          185950 non-null  object
#  1   Product           185950 non-null  object
#  2   Quantity Ordered  185950 non-null  int64
#  3   Price Each        185950 non-null  float64
#  4   Order Date        185950 non-null  object
#  5   Purchase Address  185950 non-null  object
#  6   Month             185950 non-null  int32
# dtypes: float64(1), int32(1), int64(1), object(4)
# memory usage: 10.6+ MB
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 2    176559  Bose SoundSport Headphones                 1       99.99
# 3    176560                Google Phone                 1      600.00
# 4    176560            Wired Headphones                 1       11.99
# ...

# %% [markdown]
# ## Add sales column

# %%
sales["Sales"] = sales["Quantity Ordered"] * sales["Price Each"]
sales.head(10)
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 2    176559  Bose SoundSport Headphones                 1       99.99
# 3    176560                Google Phone                 1      600.00
# 4    176560            Wired Headphones                 1       11.99
# 5    176561            Wired Headphones                 1       11.99
# 6    176562        USB-C Charging Cable                 1       11.95
# 7    176563  Bose SoundSport Headphones                 1       99.99
# 8    176564        USB-C Charging Cable                 1       11.95
# 9    176565          Macbook Pro Laptop                 1     1700.00
# 10   176566            Wired Headphones                 1       11.99
#
#         Order Date                        Purchase Address  Month    Sales
# 0   04/19/19 08:46            917 1st St, Dallas, TX 75001      4    23.90
# ...

# %% [markdown]
# # Coding exercise 3.4

# %%
supermarketFrame = pd.read_csv("supermarket_sales.csv")
supermarketFrame.info()
supermarketFrame.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1007 entries, 0 to 1006
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Invoice ID     1000 non-null   object
#  1   Branch         1000 non-null   object
#  2   City           1000 non-null   object
#  3   Customer type  1000 non-null   object
#  4   Gender         1000 non-null   object
#  5   Product line   1000 non-null   object
#  6   Unit price     1000 non-null   float64
#  7   Quantity       1000 non-null   float64
#  8   Tax 5%         1000 non-null   float64
#  9   Total          1000 non-null   float64
#  10  Date           1000 non-null   object
#  11  Time           1000 non-null   object
#  12  Payment        1000 non-null   object
# dtypes: float64(4), object(9)
# memory usage: 102.4+ KB
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# ...

# %%
supermarketFrame.isnull().sum()
# Out:
# Invoice ID       7
# Branch           7
# City             7
# Customer type    7
# Gender           7
# Product line     7
# Unit price       7
# Quantity         7
# Tax 5%           7
# Total            7
# Date             7
# Time             7
# Payment          7
# dtype: int64

# %%
supermarketFrame = supermarketFrame.dropna()
supermarketFrame.info()
supermarketFrame.head(5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1000 entries, 0 to 1006
# Data columns (total 13 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Invoice ID     1000 non-null   object
#  1   Branch         1000 non-null   object
#  2   City           1000 non-null   object
#  3   Customer type  1000 non-null   object
#  4   Gender         1000 non-null   object
#  5   Product line   1000 non-null   object
#  6   Unit price     1000 non-null   float64
#  7   Quantity       1000 non-null   float64
#  8   Tax 5%         1000 non-null   float64
#  9   Total          1000 non-null   float64
#  10  Date           1000 non-null   object
#  11  Time           1000 non-null   object
#  12  Payment        1000 non-null   object
# dtypes: float64(4), object(9)
# memory usage: 109.4+ KB
#     Invoice ID Branch       City Customer type  Gender  \
# 0  750-67-8428      A     Yangon        Member  Female
# ...

# %% [markdown]
# # Plotting data using matplotlib

# %% [markdown]
# ### 1. Which month had the highest sale? what is the monthly sales trend?
# ### 2. Which product sold the most> how are the other products doing?

# %%
# answer Q1
months = range(1,13)
monthSale = sales.groupby(["Month"]).sum()["Sales"]/1000000

plt.bar(months,monthSale)
plt.title("Monthly Sales 2019")
plt.xlabel("Month")
plt.ylabel("Sales in million USD ($)")
plt.xticks(months)

plt.show()

# %%
months = range(1,13)
monthSale = sales.groupby(["Month"]).sum()["Sales"]/1000000

plt.plot(months,monthSale)
plt.title("Monthly Sales 2019")
plt.xlabel("Month")
plt.ylabel("Sales in million USD ($)")
plt.xticks(months)

plt.show()

# %%
months = range(1,13)
monthSale = sales.groupby(["Month"]).sum()["Sales"]/1000000

plt.plot(months, monthSale, color="orange")
plt.title("Monthly Sales 2019", fontsize=14, fontweight="bold")
plt.xlabel("Month", fontsize=12, color="green")
plt.ylabel("Sales in million USD ($)", fontsize=12, color="green")
plt.xticks(months)
plt.grid(True, color="grey", linestyle=":")

for spine in plt.gca().spines.values():
    spine.set_visible(False)

plt.show()

# %%
# answer Q2
productGroup = sales.groupby("Product")
productGroup.sum()
# Out:
#                             Quantity Ordered  Price Each   Month       Sales
# Product
# 20in Monitor                            4129   451068.99   29336   454148.71
# 27in 4K Gaming Monitor                  6244  2429637.70   44440  2435097.56
# 27in FHD Monitor                        7550  1125974.93   52558  1132424.50
# 34in Ultrawide Monitor                  6199  2348718.19   43304  2355558.01
# AA Batteries (4-pack)                  27635    79015.68  145558   106118.40
# AAA Batteries (4-pack)                 31017    61716.59  146370    92740.83
# Apple Airpods Headphones               15661  2332350.00  109477  2349150.00
# Bose SoundSport Headphones             13457  1332366.75   94113  1345565.43
# Flatscreen TV                           4819  1440000.00   34224  1445700.00
# Google Phone                            5532  3315000.00   38305  3319200.00
# LG Dryer                                 646   387600.00    4383   387600.00
# ...

# %%
quantityOrdered = productGroup.sum()["Quantity Ordered"]
products = [product for product, df in productGroup]

plt.bar(products, quantityOrdered)
plt.title("Total units Sold", fontsize=12)
plt.xlabel("Products")
plt.ylabel("Units sold")
plt.xticks(products)

plt.show()

# %%
quantityOrdered = productGroup.sum()["Quantity Ordered"]
products = [product for product, df in productGroup]

plt.barh(products, quantityOrdered)
plt.title("Total units Sold", fontsize=12)
plt.xlabel("Units sold")
plt.ylabel("Products")
plt.yticks(products)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# File ~\anaconda3\envs\visualization-env\lib\site-packages\matplotlib\axis.py:1506, in Axis.convert_units(self, x)
#    1505 try:
# -> 1506     ret = self.converter.convert(x, self.units, self)
#    1507 except Exception as e:
#
# File ~\anaconda3\envs\visualization-env\lib\site-packages\matplotlib\category.py:49, in StrCategoryConverter.convert(value, unit, axis)
#      48 if unit is None:
# ---> 49     raise ValueError(
#      50         'Missing category information for StrCategoryConverter; '
#      51         'this might be caused by unintendedly mixing categorical and '
#      52         'numeric data')
#      53 StrCategoryConverter._validate_unit(unit)
#
# ValueError: Missing category information for StrCategoryConverter; this might be caused by unintendedly mixing categorical and numeric data
#
# ...
